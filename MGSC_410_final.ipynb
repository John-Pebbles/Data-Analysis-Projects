# %%
import warnings
warnings.filterwarnings('ignore')

# data imports
import pandas as pd
import numpy as np
from plotnine import *

# modeling imports
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV # Linear Regression Model
from sklearn.preprocessing import StandardScaler #Z-score variables
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error #model evaluation
from sklearn.model_selection import train_test_split, KFold, LeaveOneOut

# pipeline imports
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import make_column_transformer

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# data imports
import pandas as pd
import numpy as np
from plotnine import *

# modeling imports
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, LogisticRegression # Linear Regression Model
from sklearn.preprocessing import StandardScaler, OneHotEncoder #Z-score variables
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error, accuracy_score #model evaluation
from sklearn.model_selection import train_test_split, KFold, LeaveOneOut

# pipeline imports
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import make_column_transformer

# %matplotlib inline

# %%
#all predictors
pop = pd.read_excel("MGSC 410 Final Data-1.xlsx")

# drop missing values
# pop.isnull().sum()
pop.dropna(inplace = True)
pop.reset_index(inplace = True)

# set up X and y
predictors = ["Gender",	"City"	,"State or Province"	,"Product Family",	"Product Department",	"Product Category",	"Units Sold"]
onehot = ["Gender",	"City"	,"State or Province"	,"Product Family",	"Product Department",	"Product Category"]
contin = ["Units Sold"]

X = pop[predictors]
y = pop["Transaction Charge"]

# validation

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# z score
preprocess = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), onehot),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("pre", preprocess),
                ("linearregression", lr)])

# fit
pipe.fit(X_train,y_train)

# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
# Out:
# Train MSE :  53.106131197240735
# Train MAE :  5.621060725892825
# Train MAPE:  53.106131197240735
# Train R2  :  0.1741546921332
# Test MSE  :  58.68106125725359
# Test MAE  :  6.264953219633413
# Test MAPE :  58.68106125725359
# Test R2  :  0.08871326400061996

# %%
#all predictors minus gender
pop = pd.read_excel("MGSC 410 Final Data-1.xlsx")

# drop missing values
# pop.isnull().sum()
pop.dropna(inplace = True)
pop.reset_index(inplace = True)

# set up X and y
predictors = [	"City"	,"State or Province"	,"Product Family",	"Product Department",	"Product Category",	"Units Sold"]
onehot = [	"City"	,"State or Province"	,"Product Family",	"Product Department",	"Product Category"]
contin = ["Units Sold"]

X = pop[predictors]
y = pop["Transaction Charge"]

# validation

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# z score
preprocess = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), onehot),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("pre", preprocess),
                ("linearregression", lr)])

# fit
pipe.fit(X_train,y_train)

# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
# Out:
# Train MSE :  52.524568966103
# Train MAE :  5.668529764643228
# Train MAPE:  52.524568966103
# Train R2  :  0.16041793198047682
# Test MSE  :  64.87366087250669
# Test MAE  :  6.3196998042291455
# Test MAPE :  64.87366087250669
# Test R2  :  0.10107959143571632

# %%
#all predictors minus city
pop = pd.read_excel("MGSC 410 Final Data-1.xlsx")

# drop missing values
# pop.isnull().sum()
pop.dropna(inplace = True)
pop.reset_index(inplace = True)

# set up X and y
predictors = ["Gender"	,"State or Province"	,"Product Family",	"Product Department",	"Product Category",	"Units Sold"]
onehot = ["Gender"	,"State or Province"	,"Product Family",	"Product Department",	"Product Category"]
contin = ["Units Sold"]

X = pop[predictors]
y = pop["Transaction Charge"]

# validation

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# z score
preprocess = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), onehot),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("pre", preprocess),
                ("linearregression", lr)])

# fit
pipe.fit(X_train,y_train)

# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
# Out:
# Train MSE :  56.37019248925607
# Train MAE :  5.8303743614983174
# Train MAPE:  56.37019248925607
# Train R2  :  0.14734569799458785
# Test MSE  :  52.00556483358091
# Test MAE  :  5.69419233240192
# Test MAPE :  52.00556483358091
# Test R2  :  0.09773310494882437

# %%
#all predictors minus S or P

pop = pd.read_excel("MGSC 410 Final Data-1.xlsx")

# drop missing values
# pop.isnull().sum()
pop.dropna(inplace = True)
pop.reset_index(inplace = True)

# set up X and y
predictors = ["Gender",	"City"		,"Product Family",	"Product Department",	"Product Category",	"Units Sold"]
onehot = ["Gender",	"City"	,"Product Family",	"Product Department",	"Product Category"]
contin = ["Units Sold"]

X = pop[predictors]
y = pop["Transaction Charge"]

# validation

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# z score
preprocess = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), onehot),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("pre", preprocess),
                ("linearregression", lr)])

# fit
pipe.fit(X_train,y_train)

# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
# Out:
# Train MSE :  52.5208343849763
# Train MAE :  5.621309287740128
# Train MAPE:  52.5208343849763
# Train R2  :  0.177717729346745
# Test MSE  :  62.9503935778173
# Test MAE  :  6.290758754410897
# Test MAPE :  62.9503935778173
# Test R2  :  0.056817580912117194

# %%
#all predictors minus product family

pop = pd.read_excel("MGSC 410 Final Data-1.xlsx")

# drop missing values
# pop.isnull().sum()
pop.dropna(inplace = True)
pop.reset_index(inplace = True)

# set up X and y
predictors = ["Gender",	"City"	,"State or Province"	,	"Product Department",	"Product Category",	"Units Sold"]
onehot = ["Gender",	"City"	,"State or Province"	,	"Product Department",	"Product Category"]
contin = ["Units Sold"]

X = pop[predictors]
y = pop["Transaction Charge"]

# validation

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# z score
preprocess = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), onehot),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("pre", preprocess),
                ("linearregression", lr)])

# fit
pipe.fit(X_train,y_train)

# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
# Out:
# Train MSE :  51.93410043673746
# Train MAE :  5.647870293045759
# Train MAPE:  51.93410043673746
# Train R2  :  0.16982075795117824
# Test MSE  :  66.9883231489142
# Test MAE  :  6.403613127544495
# Test MAPE :  66.9883231489142
# Test R2  :  0.07181250302799924

# %%
#all predictors minus product department

pop = pd.read_excel("MGSC 410 Final Data-1.xlsx")

# drop missing values
# pop.isnull().sum()
pop.dropna(inplace = True)
pop.reset_index(inplace = True)

# set up X and y
predictors = ["Gender",	"City"	,"State or Province"	,"Product Family",		"Product Category",	"Units Sold"]
onehot = ["Gender",	"City"	,"State or Province"	,"Product Family",	"Product Category"]
contin = ["Units Sold"]

X = pop[predictors]
y = pop["Transaction Charge"]

# validation

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# z score
preprocess = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), onehot),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("pre", preprocess),
                ("linearregression", lr)])

# fit
pipe.fit(X_train,y_train)

# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
# Out:
# Train MSE :  53.037328350579685
# Train MAE :  5.689359305143148
# Train MAPE:  53.037328350579685
# Train R2  :  0.16482599588316105
# Test MSE  :  66.74020911924949
# Test MAE  :  6.442793593281042
# Test MAPE :  66.74020911924949
# Test R2  :  0.023526693978971447

# %%
#all predictors minus product category

pop = pd.read_excel("MGSC 410 Final Data-1.xlsx")

# drop missing values
# pop.isnull().sum()
pop.dropna(inplace = True)
pop.reset_index(inplace = True)

# set up X and y
predictors = ["Gender",	"City"	,"State or Province"	,"Product Family",	"Product Department",	"Units Sold"]
onehot = ["Gender",	"City"	,"State or Province"	,"Product Family",	"Product Department"]
contin = ["Units Sold"]

X = pop[predictors]
y = pop["Transaction Charge"]

# validation

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# z score
preprocess = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(), onehot),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("pre", preprocess),
                ("linearregression", lr)])

# fit
pipe.fit(X_train,y_train)

# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
# Out:
# Train MSE :  52.866374465986645
# Train MAE :  5.672401480583008
# Train MAPE:  52.866374465986645
# Train R2  :  0.13746372472366353
# Test MSE  :  74.27577935425401
# Test MAE  :  6.953690805006392
# Test MAPE :  74.27577935425401
# Test R2  :  0.03761854781338936

# %%
#all predictors minus units sold
pop = pd.read_excel("MGSC 410 Final Data-1.xlsx")

# drop missing values
# pop.isnull().sum()
pop.dropna(inplace = True)
pop.reset_index(inplace = True)

# set up X and y
predictors = ["Gender",	"City"	,"State or Province"	,"Product Family",	"Product Department",	"Product Category"]
onehot = ["Gender",	"City"	,"State or Province"	,"Product Family",	"Product Department",	"Product Category"]
# contin = ["Units Sold"]

X = pop[predictors]
y = pop["Transaction Charge"]

# validation

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# z score
preprocess = make_column_transformer(
                            (OneHotEncoder(), onehot),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("pre", preprocess),
                ("linearregression", lr)])

# fit
pipe.fit(X_train,y_train)

# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
# Out:
# Train MSE :  54.78509975990836
# Train MAE :  5.76193473819654
# Train MAPE:  54.78509975990836
# Train R2  :  0.1310813668656826
# Test MSE  :  70.09562231092171
# Test MAE  :  6.654234725008312
# Test MAPE :  70.09562231092171
# Test R2  :  0.0010717087419300775

# %%
R2_test = {
    'Model': ['Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5', 'Model 6', 'Model 7', 'Model 8'],
    'R_squared': [0.0887, 0.1011, 0.0977, 0.0568, 0.0718, 0.0235, 0.0376, 0.0011 ]
}

df_test = pd.DataFrame(R2_test)

(ggplot(df_test, aes(x='Model', y='R_squared')) +
 geom_col() + geom_text(aes(label='round(R_squared, 4)'), va='bottom', size=9 , color = "red") +
 labs(title='R-squared Values of Linear Regression Models for Testing Set', x='Model', y='R-squared') +
 theme(axis_text_x = element_text(angle = 45, hjust = 1))
)
# Out:
# <Figure Size: (640 x 480)>

# %%
R2_train = {
    'Model': ['Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5', 'Model 6', 'Model 7', 'Model 8'],
    'R_squared': [0.1742, 0.1604, 0.1473, 0.1778, 0.1698, 0.1648, 0.1375, 0.1311]
}

df_train = pd.DataFrame(R2_train)

(ggplot(df_train, aes(x='Model', y='R_squared')) +
 geom_col() + geom_text(aes(label='round(R_squared, 4)'), va='bottom', size=9 , color = "red") +
 labs(title='R-squared Values of Linear Regression Models for Training Set', x='Model', y='R-squared') +
 theme(axis_text_x = element_text(angle = 45, hjust = 1))
)
# Out:
# <Figure Size: (640 x 480)>
